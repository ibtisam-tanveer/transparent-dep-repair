# %% [markdown]
# # WHAT'S WRONG: needs an external data file that does not exist
# # This is NOT a dependency problem -- out of scope, must be reported honestly

# %%
with open("/no/such/data_file_xyz.csv") as f:
    data = f.read()
print(data)
