# %% [markdown]
# # WHAT'S WRONG: seaborn is not installed
# # EXPECTED ERR: ModuleNotFoundError
# # CORRECT FIX: pip install seaborn

# %%
x = 1 + 1
print(x)

# %%
import seaborn as sns
print(sns.__version__)
