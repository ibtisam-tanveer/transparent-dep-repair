# %% [markdown]
# # WHAT'S WRONG: np.float was removed in NumPy 1.24
# # EXPECTED ERR: AttributeError
# # CORRECT FIX: use float()

# %%
import numpy as np
y = 2 + 2
print(y)

# %%
x = np.float(3.14)
print(x)
